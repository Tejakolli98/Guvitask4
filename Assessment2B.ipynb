# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df1= pd.read_csv("college_1.csv")

# %%
df1.head()

# %%
df1[['python','mysql']] = df1[['python','mysql']].astype(int)
df1.head()
# Out:
#           Name  python  ...                        Department  Rising
# 0    A.Dharani      82  ...  Computer Science and Engineering       0
# 1  V.JEEVITHA       82  ...  Computer Science and Engineering       0
# 2  HEMAVATHI.R     100  ...  Computer Science and Engineering       0
# 3  Mugunthan S     100  ...  Computer Science and Engineering       0
# 4  Sathammai.S     100  ...  Computer Science and Engineering       0
#
# [5 rows x 7 columns]

# %%
df2=pd.read_csv("college_2.csv")

# %%
df2.head()
# Out:
#                 Name  python  ...                                 Department  Rising
# 0      ASHOK KUMAR K     100  ...     Electronics and Electrical Engineering       0
# 1            Chandru       0  ...           Computer Science and Engineering     340
# 2  Ganesh Ramkumar R      -1  ...           Computer Science and Engineering    2000
# 3    Bodipudi Harini      -1  ...  Electronics and Communication Engineering       0
# 4          VIINU V P      -1  ...     Electronics and Electrical Engineering       0
#
# [5 rows x 9 columns]

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df=pd.concat([df1, df2], axis=0)

# %%
df.head()
# Out:
#           Name  python  mysql  ...  Rising  python_en computational_thinking
# 0    A.Dharani      82     20  ...       0        NaN                    NaN
# 1  V.JEEVITHA       82     20  ...       0        NaN                    NaN
# 2  HEMAVATHI.R     100    100  ...       0        NaN                    NaN
# 3  Mugunthan S     100     47  ...       0        NaN                    NaN
# 4  Sathammai.S     100      8  ...       0        NaN                    NaN
#
# [5 rows x 9 columns]

# %%
df.describe().T
# Out:
#                         count         mean  ...     75%      max
# python                  119.0    54.344538  ...   100.0    100.0
# mysql                   119.0    23.478992  ...    33.0    100.0
# Previous Geekions       119.0  3842.352941  ...  5340.0  24500.0
# CodeKata Score          119.0  4051.764706  ...  5975.0  24500.0
# Rising                  119.0   209.411765  ...     0.0   3140.0
# python_en                35.0    29.657143  ...    52.0    100.0
# computational_thinking   35.0     2.200000  ...     0.0     39.0
#
# [7 rows x 8 columns]

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
Exceeded_expectations=df[df['CodeKata Score']>=15000]
Exceeded_expectations.to_csv(r'D:\PYTHON Theory\ass\New folder\Exceeded_expectations.csv', index=False)
Exceeded_expectations
# Out:
#             Name  python  mysql  ...  Rising  python_en computational_thinking
# 0      A.Dharani      82     20  ...       0        NaN                    NaN
# 1    V.JEEVITHA       82     20  ...       0        NaN                    NaN
# 2    HEMAVATHI.R     100    100  ...       0        NaN                    NaN
# 0  ASHOK KUMAR K     100     31  ...       0        0.0                    9.0
#
# [4 rows x 9 columns]

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
Reached_expectations=df[df["CodeKata Score"].between(10000, 15000, inclusive = True)]                   
Reached_expectations.to_csv(r'D:\PYTHON Theory\ass\New folder\Reached_expectations.csv', index=False)
Reached_expectations
# Out:
#                 Name  python  mysql  ...  Rising  python_en computational_thinking
# 3        Mugunthan S     100     47  ...       0        NaN                    NaN
# 1            Chandru       0      0  ...     340       20.0                    0.0
# 2  Ganesh Ramkumar R      -1     24  ...    2000       55.0                    6.0
# 3    Bodipudi Harini      -1     35  ...       0        0.0                   -1.0
#
# [4 rows x 9 columns]

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
Needs_Improvement=df[df["CodeKata Score"].between(7000, 10000, inclusive = True)]
                          
Needs_Improvement.to_csv(r'D:\PYTHON Theory\ass\New folder\Needs_Improvement.csv', index=False)
Needs_Improvement
# Out:
#                       Name  python  ...  python_en  computational_thinking
# 4              Sathammai.S     100  ...        NaN                     NaN
# 5             NIVEESHWAR S     100  ...        NaN                     NaN
# 6            KALAIARASAN K      85  ...        NaN                     NaN
# 7     MOHAMED ZUBAIR AHMED      82  ...        NaN                     NaN
# 4                VIINU V P      -1  ...      100.0                    -1.0
# 5               Poojitha Y       0  ...       78.0                     0.0
# 6   Gowtham Chandrasekaran      -1  ...        0.0                     3.0
# 7                Gowtham R      -1  ...       60.0                     6.0
# 8                 shifak N      58  ...        0.0                     0.0
# 9                  Balaji       -1  ...      100.0                     0.0
# 10                Rushitha      -1  ...       15.0                     9.0
# 11    Balaraman Muthupandi      -1  ...        9.0                     0.0
# 12                JPradhap     100  ...        0.0                     0.0
# 13           SRIRAMKUMAR B      -1  ...        0.0                     0.0
# 14               Praneetha      -1  ...       23.0                    -1.0
# 15             Rahul Raj K      -1  ...        0.0                     0.0
# 16                 Guhan S      -1  ...       72.0                    39.0
# 17            Suryarajan S      -1  ...       63.0                     0.0
#
# [18 rows x 9 columns]

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Unsatisfactory=df[df['CodeKata Score']<7000]
                          
Unsatisfactory.to_csv(r'D:\PYTHON Theory\ass\New folder\Unsatisfactory.csv', index=False)
Unsatisfactory
# Out:
#                Name  python  mysql  ...  Rising  python_en computational_thinking
# 8        J.SUGANTHI      27     50  ...       0        NaN                    NaN
# 9      thamizhpaana      29      0  ...       0        NaN                    NaN
# 10  Iyappan Samiraj      50     24  ...       0        NaN                    NaN
# 11     Ponniyamma.R     100     11  ...       0        NaN                    NaN
# 12        SABAPATHI     100      0  ...       0        NaN                    NaN
# ..              ...     ...    ...  ...     ...        ...                    ...
# 30    praveen raj j      24      0  ...       0       -1.0                    0.0
# 31       AMARNATH D      -1     12  ...       0       52.0                   -1.0
# 32             bala      32      0  ...       0       49.0                   -1.0
# 33             XY Z      -1     -1  ...       0       20.0                   -1.0
# 34        Hariharan      -1     -1  ...       0       -1.0                    0.0
#
# [93 rows x 9 columns]

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
Previous_Geekions_vs_CodeKata_Score=df[['Previous Geekions','CodeKata Score']].mean(axis=1)

Previous_Geekions_vs_CodeKata_Score
# Out:
# 0     24500.0
# 1     21740.0
# 2     19680.0
# 3     10610.0
# 4      8980.0
#        ...
# 30     2380.0
# 31     1890.0
# 32     1720.0
# 33        0.0
# 34        0.0
# Length: 119, dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
Previous_Geekions_vs_CodeKata_Score.count()
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
m= df['mysql'].mean
m
# Out:
# <bound method Series.mean of 0      20
# 1      20
# 2     100
# 3      47
# 4       8
#      ...
# 30      0
# 31     12
# 32      0
# 33     -1
# 34     -1
# Name: mysql, Length: 119, dtype: int64>

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
rising_stars_of_the_week=df.nlargest(3, 'Rising')
rising_stars_of_the_week
# Out:
#                  Name  python  mysql  ...  Rising  python_en computational_thinking
# 8            shifak N      58      0  ...    3140        0.0                    0.0
# 2   Ganesh Ramkumar R      -1     24  ...    2000       55.0                    6.0
# 18     Narasimhan Y L      -1      0  ...    2000       -1.0                    0.0
#
# [3 rows x 9 columns]

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
Shining_stars_of_the_week=df.nlargest(3, 'CodeKata Score')
Shining_stars_of_the_week
# Out:
#           Name  python  mysql  ...  Rising  python_en computational_thinking
# 0    A.Dharani      82     20  ...       0        NaN                    NaN
# 1  V.JEEVITHA       82     20  ...       0        NaN                    NaN
# 2  HEMAVATHI.R     100    100  ...       0        NaN                    NaN
#
# [3 rows x 9 columns]

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
D=df.groupby(['Department'])['CodeKata Score'].sum()
D.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f145d51fdd0>],
#       dtype=object)

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
a=df.groupby(['Department'])['CodeKata Score'].max()
a
# Out:
# Department
# Computer Science and Engineering             24500
# Electronics and Communication Engineering    10040
# Electronics and Electrical Engineering       19400
# Name: CodeKata Score, dtype: int64

# %%
a.plot.barh()
